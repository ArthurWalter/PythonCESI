# %%
import random

class CarteUno:
    def __init__(self, couleur,nombre):
        self.couleur = couleur
        self.num = nombre
        
    
    def peuxJouer(self,autre): #la fonction sert à savoir si on peut jouer une carte ou non
        if (self.num == autre.num) or (self.couleur == autre.couleur):
            return True
        return False 
    
        
    def showCarte(self): #autre manière d'arfficher une carte, sans utiliser le __str__ (vu que c'est un peu buggé)
        print(self.num,self.couleur)
       
           
class CollectionDeCarteUno(CarteUno):
    def __init__(self):
        self.l = [] #collection de cartes
        
    def addCarte(self,c):
        self.l.append(c) 
        
    def __str__(self):
        if(self.l):
            col_str = ""
            for i in range (0, len(self.l)): #pour chaque carte dans la collection
                col_str = col_str + ' ' + str(self.l[i]) #on ajoute la carte de la liste à la var col_str
            return col_str #return les objets (donc les cartes) présent dans la collection, sauf que ça marche pas super quoi
        
    def makeDeck(self): #fait un deck (puis l'affiche pour le test)
        for num in range (1,10):
            for couleur in ["jaune", "rouge", "bleu", "vert"]:
                newcard = CarteUno(couleur,num) #on génère la liste de cartes
                self.addCarte(newcard) #insertion de la liste dans le deck, on prend 2 paquets de uno
                self.addCarte(newcard)
                #str(newcard)
                #print(newcard.__str__())
                newcard.showCarte()
                                    
    def melanger(self): 
        melanger = random.randint(0,73)
                
    def print_liste(self): #on essaie d'afficher la liste sans le __str__, mais le return est chelou
        print(self.l)
    
class Partie:
    def __init__(self):
            self.Deck = CollectionDeCarteUno()
            self.Deck.makeDeck() #création du deck
            self.Deck.melanger()
            #création des joueurs
            self.main1 = CollectionDeCarteUno() #joueur1
            self.main2 = CollectionDeCarteUno() #joueur2
            self.main3 = CollectionDeCarteUno() #joueur3
            self.main4 = CollectionDeCarteUno() #joueur4
            #on initialise autant de main que le maximum possible
            nb_joueur = input("indiquer le nombre de joueur à créer, compris entre 2 et 4")
            self.joueurs = Joueur()
            for i in range(0,int(nb_joueur)):
                self.joueurs.addJoueur(i)
                #self.joueurs.showJoueur(i)    
            
            nb_joueur=self.joueurs.nombreJoueurs()
            print("nombre de joueur : ",nb_joueur)
            if(nb_joueur == 4):
                for i in range(7):
                    self.main1.addCarte(self.Deck.l.pop()) #la fonction pop permet de tirer la dernière carte du paquet, donc on tire les dernières cartes qu'on distribue aux 2 joueurs
                    self.main2.addCarte(self.Deck.l.pop()) 
                    self.main3.addCarte(self.Deck.l.pop()) # self.main3.l.addCarte ??
                    self.main4.addCarte(self.Deck.l.pop()) 
            
            elif(nb_joueur == 3):
                for i in range(7):
                    self.main1.addCarte(self.Deck.l.pop()) 
                    self.main2.addCarte(self.Deck.l.pop()) 
                    self.main3.addCarte(self.Deck.l.pop()) 
                    del(self.main4)#delete joueur4
                    
                   # if not self.main4 :
                    #    print('pas de main 4')
                
            elif(nb_joueur == 2):
                for i in range(7):
                    self.main1.addCarte(self.Deck.l.pop()) 
                    self.main2.addCarte(self.Deck.l.pop()) 
                    del(self.main3)#delete joueur3
                    del(self.main4)#delete joueur4
            else:
                print("vous n'avez pas saisi un nombre de joueurs compris entre 2 et 4")
            
    def JouerLaGame(self):
        self.main1.l.pop() #la main1 commence tous le temps
        self.DernierCarte = self.main1.l.pop() #on joue la dernière carte de la liste dans la main du joueur1

        while(True):
            #self.Jouer(1) #joueur1 #ordre horaire
            #self.Jouer(2) #joueur2
            #self.Jouer(3) #joueur3
            #self.Jouer(4) #joueur4  
            
             #if len(self.main1.l) == 0 or len(self.main2.l) == 0 or len(self.main3.l) == 0 or len(self.main4.l) == 0:
                #donc on joue jusqu'à ce qu'une carte ne possède plus de cartes
                #if len(self.main1.l) == 0: #si plus de cartes
                    #print("Le joueur 1 gagne")
                #elif len(self.main2.l) == 0: 
                    #print("Le joueur 2 gagne")
                #elif len(self.main3.l) == 0: 
                    #print("Le joueur 3 gagne")
                #elif len(self.main4.l) == 0: 
                    #print("Le joueur 4 gagne")
                #else:
                    #print("La game est cheloue.")
                    
            #faut modifier pour mettre la liste de la classe joueur
            #genre :
            
            for i in range(0,3): #joueurs.nombreJoueurs()
                self.Jouer(i)
                if(i==0):
                    if len(self.main1.l) == 0:
                        print("Le joueur 1 gagne")
                        return False 
                elif(i==1):
                    if len(self.main2.l) == 0:
                        print("Le joueur 2 gagne")
                        return False 
                elif(i==2):
                    if len(self.main3.l) == 0:
                        print("Le joueur 3 gagne")
                        return False 
                elif(i==3):
                    if len(self.main4.l) == 0:
                        print("Le joueur 4 gagne")
                        return False 

    def Jouer(self, Joueur):
        #self.DerniereCarte = self.main1.pop()
        if Joueur==1:
            if self.main1.peuxJouer(self.main1[-1]): #test si la carte peut être joué via la fonction peut jouer 
                self.main1.pop() 
                #self.DerniereCarte = self.main1.pop() #la prochaine carte est la dernière de la liste dans la main du joueur
            else:
                self.main1.addCarte(self.Deck.pop()) #pioche une carte dans la pioche puisque la dernière carte ne peut pas être joué
        elif Joueur==2:
            if self.main2.peuxJouer(self.main1[-1]):
                self.main2.pop() 
                
            else:
                self.main2.addCarte(self.Deck.pop())
        elif Joueur==3:
            if self.main3.peuxJouer(self.main1[-1]):
                self.main3.pop() 
                
            else:
                self.main3.addCarte(self.Deck.pop())
        elif Joueur==4:
            if self.main4.peuxJouer(self.main1[-1]):
                self.main4.pop() 
                
            else:
                self.main4.addCarte(self.Deck.pop())

    def printResultats(self): #print les mains à la fin de la game
        print (main1)
        print (main2)
        print (main3)
        print (main4)
            
class Joueur(CollectionDeCarteUno):
    def __init__(self):
        self.joueurs=[] 

    def addJoueur(self,id):
        self.joueurs.append(id)
        
    def showJoueur(self,i):
        print(self.joueurs[i])
    
    def nombreJoueurs(self):
        #print("longueurs : ",len(self.joueurs))
        return len(self.joueurs)
        
        
    
#classe joueur
#var mains
#méthodes et fonctions draw
        
main = Partie() #lance la game
main.JouerLaGame()
# Out:
# 1 jaune
# 1 rouge
# 1 bleu
# 1 vert
# 2 jaune
# 2 rouge
# 2 bleu
# 2 vert
# 3 jaune
# 3 rouge
# 3 bleu
# 3 vert
# 4 jaune
# 4 rouge
# 4 bleu
# 4 vert
# 5 jaune
# 5 rouge
# 5 bleu
# 5 vert
# 6 jaune
# 6 rouge
# 6 bleu
# 6 vert
# 7 jaune
# 7 rouge
# 7 bleu
# 7 vert
# 8 jaune
# 8 rouge
# 8 bleu
# 8 vert
# 9 jaune
# 9 rouge
# 9 bleu
# 9 vert
# indiquer le nombre de joueur à créer, compris entre 2 et 4 4
# nombre de joueur :  4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-bc9976546be6> in <module>
#     191
#     192 main = Partie() #lance la game
# --> 193 main.JouerLaGame()
#
# <ipython-input-18-bc9976546be6> in JouerLaGame(self)
#     119
#     120             for i in range(0,3): #joueurs.nombreJoueurs()
# --> 121                 self.Jouer(i)
#     122                 if(i==0):
#     123                     if len(self.main1.l) == 0:
#
# ...
